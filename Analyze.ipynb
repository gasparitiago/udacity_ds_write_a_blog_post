# %% [markdown]
# # Data Analysis on Rio de Janeiro Airbnb dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read the CSV. Downloaded from http://insideairbnb.com/get-the-data.html

# %%
df = pd.read_csv('listings.csv')
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  17878  https://www.airbnb.com/rooms/17878  20210717121617   2021-07-17
# 1  24480  https://www.airbnb.com/rooms/24480  20210717121617   2021-07-17
# 2  25026  https://www.airbnb.com/rooms/25026  20210717121617   2021-07-17
# 3  35636  https://www.airbnb.com/rooms/35636  20210717121617   2021-07-18
# 4  35764  https://www.airbnb.com/rooms/35764  20210717121617   2021-07-17
#
#                                                 name  \
# 0  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1                   Nice and cozy near Ipanema Beach
# 2          Beautiful Modern Decorated Studio in Copa
# 3                   Cosy flat close to Ipanema beach
# 4     COPACABANA SEA BREEZE  -  RIO - 20 X Superhost
#
#                                          description  \
# 0  Discounts for long term stays. <br />- Large b...
# 1  My studio is located in the best  of Ipanema. ...
# 2  Our apartment is a little gem, everyone loves ...
# 3  This cosy apartment  is just a few steps away ...
# 4  Our newly renovated studio is located in the b...
#
#                                neighborhood_overview  \
# 0  This is the one of the bests spots in Rio. Bec...
# 1  The beach, the lagoon, Ipanema is a great loca...
# 2  Copacabana is a lively neighborhood and the ap...
# 3  The  apartment street is very quiet and safe ....
# 4  Our guests will experience living with a local...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/65320518/3069...    68997
# 1  https://a0.muscache.com/pictures/11955612/b28e...    99249
# 2  https://a0.muscache.com/pictures/3003965/68ebb...   102840
# 3  https://a0.muscache.com/pictures/20009355/38b6...   153232
# 4  https://a0.muscache.com/pictures/23782972/1d3e...   153691
#
#                                    host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/68997  ...                        4.90
# 1   https://www.airbnb.com/users/show/99249  ...                        4.90
# 2  https://www.airbnb.com/users/show/102840  ...                        4.90
# 3  https://www.airbnb.com/users/show/153232  ...                        4.88
# 4  https://www.airbnb.com/users/show/153691  ...                        4.94
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   4.76                4.65     NaN                t
# 1                   4.97                4.58     NaN                f
# 2                   4.81                4.56     NaN                f
# 3                   4.90                4.65     NaN                f
# 4                   4.93                4.87     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              1                                           1
# 2                              2                                           2
# 3                              1                                           1
# 4                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              2.11
# 1                                           0              0.88
# 2                                           0              1.89
# 3                                           0              1.97
# 4                                           0              3.05
#
# [5 rows x 74 columns]

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  2.363500e+04  2.363500e+04  2.363500e+04         23628.000000
# mean   2.583630e+07  2.021072e+13  1.017046e+08             8.689521
# std    1.620414e+07  0.000000e+00  1.110507e+08            31.028486
# min    1.787800e+04  2.021072e+13  3.607000e+03             0.000000
# 25%    1.230374e+07  2.021072e+13  1.407128e+07             1.000000
# 50%    2.494374e+07  2.021072e+13  6.029813e+07             2.000000
# 75%    4.139697e+07  2.021072e+13  1.562663e+08             4.000000
# max    5.109122e+07  2.021072e+13  4.131633e+08           433.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               23628.000000                           0.0  23635.000000
# mean                    8.689521                           NaN    -22.966148
# std                    31.028486                           NaN      0.035113
# min                     0.000000                           NaN    -23.072620
# 25%                     1.000000                           NaN    -22.984680
# 50%                     2.000000                           NaN    -22.972000
# 75%                     4.000000                           NaN    -22.951960
# max                   433.000000                           NaN    -22.749690
#
#           longitude  accommodates  bathrooms  ...  review_scores_checkin  \
# count  23635.000000  23635.000000        0.0  ...           14501.000000
# mean     -43.249278      4.139454        NaN  ...               4.872734
# std        0.097131      2.493865        NaN  ...               0.389450
# min      -43.720990      0.000000        NaN  ...               0.000000
# 25%      -43.306905      2.000000        NaN  ...               4.900000
# 50%      -43.196360      4.000000        NaN  ...               5.000000
# 75%      -43.186300      5.000000        NaN  ...               5.000000
# max      -43.104400     16.000000        NaN  ...               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                 14503.000000            14500.000000
# mean                      4.851966                4.847638
# std                       0.415206                0.377966
# min                       1.000000                1.000000
# 25%                       4.880000                4.850000
# 50%                       5.000000                5.000000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  license  calculated_host_listings_count  \
# count         14501.000000      0.0                    23635.000000
# mean              4.630632      NaN                        7.396361
# std               0.510273      NaN                       22.759622
# min               1.000000      NaN                        1.000000
# 25%               4.500000      NaN                        1.000000
# 50%               4.750000      NaN                        1.000000
# 75%               5.000000      NaN                        3.000000
# max               5.000000      NaN                      195.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 23635.000000
# mean                                      6.492575
# std                                      22.147644
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                     191.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  23635.000000
# mean                                       0.796446
# std                                        1.683511
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       11.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 23635.000000       14980.000000
# mean                                      0.086355           0.602536
# std                                       0.614511           0.864291
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.090000
# 50%                                       0.000000           0.240000
# 75%                                       0.000000           0.790000
# max                                      11.000000          26.960000
#
# [8 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ## Code to answer the question: Does the GeoLocation of a property affect its price?

# %%
# Get the latitude, longitude and price
df_geo = df[['latitude', 'longitude', 'price']]

# Drop the NA values because we just need to evaluate the real properties that have the three information
df_geo.dropna()

# Convert the prices to float to improve the analysis
df_geo['price'] = df_geo['price'].str.replace(',', '')
df_geo['price'] = df_geo['price'].str.replace('$', '')
df_geo['price'] = df_geo['price'].astype(float)
df_geo.describe()
# Out:
# /var/folders/pt/zrk7x6q129l0kc42bc7l9fhw0000gn/T/ipykernel_619/1917420553.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geo['price'] = df_geo['price'].str.replace(',', '')
# /var/folders/pt/zrk7x6q129l0kc42bc7l9fhw0000gn/T/ipykernel_619/1917420553.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_geo['price'] = df_geo['price'].str.replace('$', '')
# /var/folders/pt/zrk7x6q129l0kc42bc7l9fhw0000gn/T/ipykernel_619/1917420553.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geo['price'] = df_geo['price'].str.replace('$', '')
# /var/folders/pt/zrk7x6q129l0kc42bc7l9fhw0000gn/T/ipykernel_619/1917420553.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geo['price'] = df_geo['price'].astype(float)
#            latitude     longitude          price
# count  23635.000000  23635.000000   23635.000000
# mean     -22.966148    -43.249278     751.329300
# std        0.035113      0.097131    5477.207312
# min      -23.072620    -43.720990       0.000000
# 25%      -22.984680    -43.306905     150.000000
# 50%      -22.972000    -43.196360     256.000000
# 75%      -22.951960    -43.186300     511.000000
# max      -22.749690    -43.104400  586229.000000

# %%
# As we can see, the max price is way bigger than the quarter values.
# It seems to be some spurious values. So let's keep the values between 1 and 5,000
df_geo = df_geo[df_geo['price'].between(1, 5000)]

# %%
# Analyzing the histograms
df_geo.hist(bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'longitude'}>],
#        [<AxesSubplot:title={'center':'price'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# Getting the correlation of latitude, longitude and price
df_geo.corr()
# Out:
#            latitude  longitude     price
# latitude   1.000000   0.343188 -0.162098
# longitude  0.343188   1.000000 -0.127245
# price     -0.162098  -0.127245  1.000000

# %%
# Visualizing the price in a map
df_geo.plot(kind="scatter", x="longitude", y="latitude", figsize=(10,7),
    c="price", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
# Getting the minimum and maximum to download the map used to plot the data
bounding_box = ((df_geo.longitude.min(), df_geo.longitude.max(),      
                 df_geo.latitude.min(), df_geo.latitude.max()))
bounding_box
# Out:
# (-43.72099, -43.1044, -23.07262, -22.74969)

# %%
from matplotlib.pyplot import figure

# Reading the map exported in the OpenStreetmap website: https://www.openstreetmap.org/export#map=11/-22.9116/-43.4983
map = plt.imread('map.png')

plt.figure(figsize=(15, 15))
im = plt.scatter(df_geo.longitude, df_geo.latitude, c=df_geo.price, s=20, cmap='jet')
plt.axis('off')
cbar = plt.colorbar(im,fraction=0.02)
cbar.set_label('Prices')
plt.imshow(map, zorder=0, extent = bounding_box, aspect= 'equal')

# %% [markdown]
# ## Question 2: Which amenities are more common in Rio

# %%
# Using the MultiLabelBinarizer from sklearn to break amenities into different columns
# This is necessary to analyze each amenity independetely.

from sklearn.preprocessing import MultiLabelBinarizer
amenities_df = df['amenities'].map(lambda amenity: [list.replace('"', '').replace('/', '').replace('{', '').replace('}', '') for list in amenity.split(',')])
multi_label_binarizer = MultiLabelBinarizer()
amenities_multi = pd.DataFrame(multi_label_binarizer.fit_transform(amenities_df), columns=multi_label_binarizer.classes_, index=amenities_df.index)

# %%
most_common = amenities_multi.sum().sort_values(ascending = False)[:10] / (amenities_multi.count()[0])
plt.bar(most_common.index, most_common.values)
plt.title('Amenities')
plt.xlabel('Amenities')
plt.ylabel('Percentage')
plt.xticks(rotation = 90);

# %%
list(amenities_multi.columns)
# Out:
# ['  Amenities Realgem\\u2019s -Talentos do Brasil Feita a base de mel',
#  '  Electrolux refrigerator',
#  '  Electrolux stainless steel gas stove',
#  '  Electrolux stainless steel oven',
#  '  c Congelador Separado refrigerator',
#  '  linens',
#  ' 02 Bocas electric stove',
#  ' 02 bocas cforno gas stove',
#  ' 04 bocas cforno gas stove',
#  ' 1 boca Fischer induction stove',
#  ' 14\\ TV with standard cable',
#  ' 17\\ TV with standard cable',
#  ' 17\\ TV]',
#  ' 19\\ HDTV with standard cable',
#  ' 2 Burner Hot plate electric stove',
#  ' 2 bocas electric stove',
#  ' 2 caixas de 45w cada',
#  ' 2 caixas sony Bluetooth sound system',
#  ' 2 in 1. sound system with aux',
#  ' 2-5 years old',
#  ' 20\\ HDTV with premium cable',
#  ' 20\\ TV with standard cable',
#  ' 21\\ HDTV with standard cable',
#  ' 21\\ TV',
#  ' 21\\ TV with standard cable',
#  ' 22\\ HDTV with Netflix',
#  ' 24\\ HDTV with Netflix',
#  ' 24\\ HDTV with standard cable',
#  ' 24\\ TV',
#  ' 25\\ TV with Chromecast',
#  ' 26\\ HDTV with Netflix',
#  ' 27\\ HDTV with standard cable',
#  ' 27\\ TV with standard cable',
#  ' 28\\ HDTV with standard cable',
#  ' 29\\ HDTV with standard cable',
#  ' 29\\ TV with standard cable',
#  ' 30\\ HDTV with Amazon Prime Video',
#  ' 32\\ HDTV',
#  ' 32\\ HDTV with Amazon Prime Video',
#  ' 32\\ HDTV with Chromecast',
#  ' 32\\ HDTV with Netflix',
#  ' 32\\ HDTV with Roku',
#  ' 32\\ HDTV with ]',
#  ' 32\\ HDTV with premium cable',
#  ' 32\\ HDTV with standard cable',
#  ' 32\\ TV',
#  ' 32\\ TV with Amazon Prime Video',
#  ' 32\\ TV with Netflix',
#  ' 32\\ TV with premium cable',
#  ' 32\\ TV with standard cable',
#  ' 33\\ TV',
#  ' 33\\ TV with standard cable',
#  ' 35 canais de r\\u00e1dio e m\\u00fasica na TV a cabo  sound system',
#  ' 37\\ TV with Chromecast',
#  ' 38\\ HDTV with premium cable',
#  ' 38\\ HDTV with standard cable',
#  ' 4 Bocas gas stove',
#  ' 4 bocas gas stove',
#  ' 40\\ HDTV',
#  ' 40\\ HDTV with Chromecast',
#  ' 40\\ HDTV with HBO Max',
#  ' 40\\ HDTV with Netflix',
#  ' 40\\ HDTV with Roku',
#  ' 40\\ HDTV with premium cable',
#  ' 40\\ HDTV with standard cable',
#  ' 40\\ TV',
#  ' 40\\ TV with Amazon Prime Video',
#  ' 40\\ TV with Roku',
#  ' 40\\ TV with standard cable',
#  ' 42\\ HDTV',
#  ' 42\\ HDTV with Amazon Prime Video',
#  ' 42\\ HDTV with Apple TV',
#  ' 42\\ HDTV with Chromecast',
#  ' 42\\ HDTV with Netflix',
#  ' 42\\ HDTV with premium cable',
#  ' 42\\ HDTV with standard cable',
#  ' 42\\ TV',
#  ' 42\\ TV with Chromecast',
#  ' 42\\ TV with Netflix',
#  ' 42\\ TV with Roku',
#  ' 42\\ TV with standard cable',
#  ' 43\\ HDTV',
#  ' 43\\ HDTV with Amazon Prime Video',
#  ' 43\\ HDTV with Netflix',
#  ' 43\\ HDTV with premium cable',
#  ' 43\\ HDTV with standard cable',
#  ' 43\\ TV',
#  ' 43\\ TV with Chromecast',
#  ' 43\\ TV with Netflix',
#  ' 43\\ TV with standard cable',
#  ' 44\\ HDTV with Chromecast',
#  ' 45\\ HDTV with Netflix',
#  ' 45\\ TV with standard cable',
#  ' 46\\ HDTV with standard cable',
#  ' 46\\ TV with standard cable',
#  ' 47\\ HDTV with Netflix',
#  ' 47\\ HDTV with premium cable',
#  ' 47\\ HDTV with standard cable',
#  ' 48\\ HDTV with Netflix',
#  ' 48\\ HDTV with standard cable',
#  ' 48\\ TV',
#  ' 48\\ TV with Netflix',
#  ' 49\\ HDTV with Amazon Prime Video',
#  ' 49\\ HDTV with Netflix',
#  ' 49\\ HDTV with premium cable',
#  ' 49\\ HDTV with standard cable',
#  ' 5% do valor das vendas dos cosm\\u00e9ticos \\u00e9 destinado \\u00e0 Cooperativa fabricante da mat\\u00e9ria-prima Outro diferencial \\u00e9 que estes cosm\\u00e9ticos s\\u00e3o os \\u00fanicos do mercado hoteleiro altamente sustent\\u00e1veis e homologados pelo Minist\\u00e9rio do Turismo',
#  ' 5-10 years old',
#  ' 50\\ HDTV',
#  ' 50\\ HDTV with Amazon Prime Video',
#  ' 50\\ HDTV with Chromecast]',
#  ' 50\\ HDTV with Netflix',
#  ' 50\\ HDTV with premium cable',
#  ' 50\\ HDTV with standard cable',
#  ' 50\\ TV',
#  ' 50\\ TV with Netflix',
#  ' 50\\ TV with Roku',
#  ' 50\\ TV with standard cable',
#  ' 52\\ HDTV',
#  ' 52\\ HDTV with Amazon Prime Video',
#  ' 52\\ HDTV with Chromecast',
#  ' 52\\ HDTV with Netflix',
#  ' 52\\ HDTV with standard cable',
#  ' 52\\ TV',
#  ' 53\\ HDTV with premium cable',
#  ' 55\\ HDTV',
#  ' 55\\ HDTV with Amazon Prime Video',
#  ' 55\\ HDTV with Netflix',
#  ' 55\\ HDTV with premium cable',
#  ' 55\\ HDTV with standard cable',
#  ' 55\\ TV with Chromecast',
#  ' 56\\ TV',
#  ' 57\\ HDTV with Amazon Prime Video',
#  ' 58\\ HDTV with Amazon Prime Video',
#  ' 58\\ HDTV with Chromecast',
#  ' 58\\ HDTV with HBO Max',
#  ' 6 bocas gas stove',
#  ' 60\\ HDTV with Amazon Prime Video',
#  ' 60\\ HDTV with Netflix',
#  ' 60\\ TV with standard cable',
#  ' 65\\ HDTV with Amazon Prime Video',
#  ' 65\\ HDTV with premium cable',
#  ' 65\\ HDTV with standard cable',
#  ' 65\\ TV with premium cable',
#  ' 70\\ HDTV with Netflix',
#  ' 70\\ HDTV with standard cable',
#  ' 75\\ HDTV with Netflix',
#  ' 75\\ HDTV with standard cable',
#  ' 78 liters refrigerator',
#  ' AIKO',
#  ' ATLAS gas stove',
#  ' Acompanha o fogao oven',
#  ' Acoplado ao fog\\u00e3o',
#  ' Agratto stainless steel electric stove',
#  ' Air conditioning',
#  ' Air conditioning]',
#  ' Airport shuttle',
#  ' Akai old-school but good for listening to music and radio sound system with aux',
#  ' Aksoi gas stove',
#  ' Alexa Echo Dot sound system',
#  ' Amazon Alexa Bluetooth sound system',
#  ' Amazon Prime Video',
#  ' Amenities body soap',
#  ' Amostras shampoo',
#  ' Apple TV',
#  ' Ar condicionado de janela em todos os quartos conditioner',
#  ' Arno conditioner',
#  ' Atlas  gas stove',
#  ' Atlas stainless steel gas stove',
#  ' Atlas stainless steel oven',
#  ' BBQ grill',
#  ' BBQ grill]',
#  ' BOSCH KDN 49 refrigerator',
#  ' BOSCH stainless steel gas stove',
#  ' BOSE sound system',
#  ' BRASTEMP refrigerator',
#  ' BRASTEMP stainless steel gas stove',
#  ' BRASTEMP stainless steel oven',
#  ' B\\u00e1sico conditioner',
#  ' Baby bath',
#  ' Baby monitor',
#  ' Baby safety gates',
#  ' Babysitter recommendations',
#  ' Backyard',
#  ' Baking sheet',
#  ' Barbecue utensils',
#  ' Barra marcas populares body soap',
#  ' Basico conditioner',
#  ' Bathroom essentials',
#  ' Bathroom essentials]',
#  ' Bathtub',
#  ' Beach essentials',
#  ' Beach essentials]',
#  ' Beachfront',
#  ' Beachfront]',
#  ' Bed linens',
#  ' Bed linens]',
#  ' Bed sheets and pillows',
#  ' Bedroom comforts',
#  ' Bi-plex refrigerator',
#  ' Bidet',
#  ' Bikes',
#  ' Bluetooth sound system',
#  ' Board games',
#  ' Boat slip',
#  ' Body soap',
#  ' Bosch oven',
#  ' Bosch refrigerator',
#  ' Bosch stainless steel oven',
#  ' Bosch stove',
#  ' Bose Bluetooth sound system',
#  ' Bose sound system with Bluetooth and aux',
#  ' Bottled water',
#  ' Brastemp',
#  ' Brastemp  gas stove',
#  ' Brastemp  refrigerator',
#  ' Brastemp  stainless steel gas stove',
#  ' Brastemp - Duplex refrigerator',
#  ' Brastemp - Frigobar Vintage  refrigerator',
#  ' Brastemp 460 l refrigerator',
#  ' Brastemp 5 bocas stainless steel gas stove',
#  ' Brastemp Bancada stainless steel gas stove',
#  ' Brastemp Clean refrigerator',
#  ' Brastemp Duplex refrigerator',
#  ' Brastemp Frost-free 480 l com bebedouro na porta refrigerator',
#  ' Brastemp Inverse refrigerator',
#  ' Brastemp Inverter refrigerator',
#  ' Brastemp Retr\\u00f4 refrigerator',
#  ' Brastemp electric stove',
#  ' Brastemp gas stove',
#  ' Brastemp inverse refrigerator',
#  ' Brastemp oven',
#  ' Brastemp refrigerator',
#  ' Brastemp side by side refrigerator',
#  ' Brastemp stainless steel electric stove',
#  ' Brastemp stainless steel gas stove',
#  ' Brastemp stainless steel oven',
#  ' Brastemp stainless steel stove',
#  ' Brastemp stove',
#  ' Brastempe stove',
#  ' Bread maker',
#  ' Breakfast',
#  ' Breakfast]',
#  ' Brit\\u00e2nia  stainless steel oven',
#  ' Britania oven',
#  ' Building staff',
#  ' Building staff]',
#  ' CONSUL 240 litros com congelador interno refrigerator',
#  ' CONSUL gas stove',
#  ' CONSUL refrigerator',
#  ' C\\u00f4nsul  Wirpool gas stove',
#  ' C\\u00f4nsul  Wirpool refrigerator',
#  ' C\\u00f4nsul stainless steel oven',
#  ' Cable TV',
#  ' Cable TV]',
#  ' Cadence stove',
#  ' Caixas de som bluetooth embutidas para conex\\u00e3o pelo celular Bluetooth sound system',
#  ' Cambridge Audio sound system with aux',
#  ' Carbon monoxide alarm',
#  ' Ceiling fan',
#  ' Ceiling fan]',
#  ' Central air conditioning',
#  ' Central heating',
#  ' Changing table',
#  ' Children\\u2019s books and toys',
#  ' Children\\u2019s books and toys for ages 0-2 years old',
#  ' Children\\u2019s books and toys for ages 0-2 years old and 2-5 years old',
#  ' Children\\u2019s books and toys for ages 10+ years old',
#  ' Children\\u2019s books and toys for ages 2-5 years old',
#  ' Children\\u2019s books and toys for ages 2-5 years old and 5-10 years old',
#  ' Children\\u2019s books and toys for ages 5-10 years old',
#  ' Children\\u2019s books and toys for ages 5-10 years old and 10+ years old',
#  ' Children\\u2019s dinnerware',
#  ' Chromecast',
#  ' Chromecast]',
#  ' Cleaning before checkout',
#  ' Cleaning before checkout]',
#  ' Cleaning products',
#  ' Clothing storage',
#  ' Clothing storage: closet',
#  ' Clothing storage: closet and dresser',
#  ' Clothing storage: closet and walk-in closet',
#  ' Clothing storage: closet and wardrobe',
#  ' Clothing storage: dresser',
#  ' Clothing storage: dresser and closet',
#  ' Clothing storage: dresser and walk-in closet',
#  ' Clothing storage: dresser and wardrobe',
#  ' Clothing storage: walk-in closet',
#  ' Clothing storage: walk-in closet and dresser',
#  ' Clothing storage: walk-in closet and wardrobe',
#  ' Clothing storage: wardrobe',
#  ' Clothing storage: wardrobe and closet',
#  ' Clothing storage: wardrobe and dresser',
#  ' Clothing storage: wardrobe and walk-in closet',
#  ' Clothing storage]',
#  ' Coffee maker',
#  ' Coffee maker]',
#  ' Com congelador \\u00e0 parte refrigerator',
#  ' Com freezer refrigerator',
#  ' Complimentary breakfast',
#  ' Complimentary breakfast buffet',
#  ' Comum body soap',
#  ' Concierge',
#  ' Condicionador Ceramidas e Xampu  Queratina body soap',
#  ' Condicionador Ceramidas e Xampu  Queratina conditioner',
#  ' Condicionador Ceramidas e Xampu  Queratina shampoo',
#  ' Condicionador Ceramidas e Xampu  Queratinaa body soap',
#  ' Conditioner',
#  ' Consul',
#  ' Consul  2 portas refrigerator',
#  ' Consul  Wirpool oven',
#  ' Consul 240 litros refrigerator',
#  ' Consul 280 L refrigerator',
#  ' Consul 280L refrigerator',
#  ' Consul 4 bocas a g\\u00e1s encanado GN acendimento super autom\\u00e1tico (220V) gas stove',
#  ' Consul 400 litros refrigerator',
#  ' Consul Duplex Frost Free refrigerator',
#  ' Consul Duplex frost free refrigerator',
#  ' Consul Frost Free 342l refrigerator',
#  ' Consul Novo gas stove',
#  ' Consul duas portas refrigerator',
#  ' Consul frost free refrigerator',
#  ' Consul gas stove',
#  ' Consul novo refrigerator',
#  ' Consul oven',
#  ' Consul refrigerator',
#  ' Consul stainless steel gas stove',
#  ' Consul stainless steel gas stove]',
#  ' Consul stainless steel oven',
#  ' Consul stainless steel stove',
#  ' Continental Duplex refrigerator',
#  ' Continental gas stove',
#  ' Continental stainless steel gas stove',
#  ' Continental stainless steel oven',
#  ' Continental stove',
#  ' Convencional oven',
#  ' Cook gas stove',
#  ' Cook top gas stove',
#  ' Cooking basics',
#  ' Cooktop - 1 boca induction stove',
#  ' Cooktop 2 bocas gas stove',
#  ' Cooktop 2 bocas stove',
#  ' Cooktop 2 queimadores sem forno stainless steel gas stove',
#  ' Cooktop 4 bocas Brastemp gas stove',
#  ' Cooktop 4 queimadores sem forno gas stove',
#  ' Cooktop Brastemp  stainless steel gas stove',
#  ' Cooktop Marca Franke stainless steel gas stove',
#  ' Cooktop Sugar 2 bocas stainless steel stove',
#  ' Cooktop com 2 bocas gas stove',
#  ' Cooktop duas bocas el\\u00e9trico stainless steel electric stove',
#  ' Cooktop electric stove',
#  ' Cooktop gas stove',
#  ' Cooktop port\\u00e1til induction stove',
#  ' Cooktop stainless steel gas stove',
#  ' Cooktop stove',
#  ' Cozinha b\\u00e1sica para pequenas refei\\u00e7\\u00f5es. electric stove',
#  ' Crib',
#  ' Crib]',
#  ' D&D gas stove',
#  ' DENON Bluetooth sound system',
#  ' DOVE OU N\\u00cdVEA ( NOVOS ) body soap',
#  ' DOVE body soap',
#  ' Dako gas stove',
#  ' Dedicated workspace',
#  ' Dedicated workspace: desk',
#  ' Dedicated workspace: desk and office chair',
#  ' Dedicated workspace: desk and office chair]',
#  ' Dedicated workspace: desk and table',
#  ' Dedicated workspace: monitor',
#  ' Dedicated workspace: office chair',
#  ' Dedicated workspace: office chair and desk',
#  ' Dedicated workspace: office chair and table',
#  ' Dedicated workspace: table',
#  ' Dedicated workspace: table and desk',
#  ' Dedicated workspace: table and office chair',
#  ' Dedicated workspace]',
#  ' Deixamos um mini-sabonete Calgary',
#  ' Dining table',
#  ' Dishes and silverware',
#  ' Dishes and silverware]',
#  ' Dishwasher',
#  ' Dispenser com Sabonete L\\u00edquido Erva Doce',
#  ' Disponibilizado um novo a cada estadia body soap',
#  ' Diversas body soap',
#  ' Diverso conditioner',
#  ' Diverso shampoo]',
#  ' Dove',
#  ' Dove  Nivea body soap',
#  ' Dove  body soap',
#  ' Dove Original body soap',
#  ' Dove body soap',
#  ' Dove conditioner',
#  ' Dove ou Lux body soap',
#  ' Dove ou Nivea body soap',
#  ' Dove ou similar body soap',
#  ' Dove ou similar shampoo',
#  ' Dove shampoo',
#  ' Dove. N\\u00edvea . Granado.  body soap',
#  ' DoveNivea body soap',
#  ' Dryer',
#  ' Dryer \\u2013 In building',
#  ' Dryer \\u2013\\u00a0In unit',
#  ' Dryer]',
#  ' Drying rack for clothing',
#  ' Duplex Eletrolux refrigerator',
#  ' ELETRICO BRITANIA oven',
#  ' ELETROLUX refrigerator',
#  ' ELETROLUX stainless steel gas stove',
#  ' ELETROLUX stainless steel oven',
#  ' EV charger]',
#  ' El\\u00e9trico pequeno (Forninho) oven',
#  ' Electric stove',
#  ' Electrolux  refrigerator',
#  ' Electrolux  stainless steel gas stove',
#  ' Electrolux  stainless steel oven',
#  ' Electrolux - Refrigerador com Freezer - 360 litros refrigerator',
#  ' Electrolux 300 litros refrigerator',
#  ' Electrolux Side by Side refrigerator',
#  ' Electrolux duplex frost free refrigerator',
#  ' Electrolux gas stove',
#  ' Electrolux refrigerator',
#  ' Electrolux stainless steel gas stove',
#  ' Electrolux stainless steel oven',
#  ' Electrolux. Duplex. refrigerator',
#  ' Eletroclux refrigerator',
#  ' Eletrolix inox 2 portas refrigerator',
#  ' Eletrolux - G\\u00e1s stainless steel oven',
#  ' Eletrolux 2 fornos stainless steel gas stove',
#  ' Eletrolux 2 portas refrigerator',
#  ' Eletrolux DF52X refrigerator',
#  ' Eletrolux Duas Portas refrigerator',
#  ' Eletrolux Frost Free  refrigerator',
#  ' Eletrolux a\\u00e7o 5 bocas stainless steel gas stove',
#  ' Eletrolux de 6 bocas  com forno gas stove',
#  ' Eletrolux de 6 bocas com forno oven',
#  ' Eletrolux frost free  refrigerator',
#  ' Eletrolux gas stove',
#  ' Eletrolux oven',
#  ' Eletrolux refrigerator',
#  ' Eletrolux stainless steel gas stove',
#  ' Eletrolux stainless steel oven',
#  ' Eletrolux stove',
#  ' Elevator',
#  ' Elevator]',
#  ' Elletrolux',
#  ' Elseve Loreal conditioner',
#  ' Elseve Loreal shampoo',
#  ' Elseve conditioner',
#  ' Elseve shampoo',
#  ' Embutido oven',
#  ' Erva doce  body soap',
#  ' Erva doce body soap',
#  ' Erva doce conditioner',
#  ' Esmaltec  stove',
#  ' Esmaltec 4 Bocas stainless steel gas stove',
#  ' Esmaltec gas stove',
#  ' Essentials',
#  ' Essentials]',
#  ' Ethernet connection',
#  ' Extra pillows and blankets',
#  ' Extra pillows and blankets]',
#  ' Fire extinguisher',
#  ' Fire extinguisher]',
#  ' Fire pit',
#  ' Fireplace guards',
#  ' First aid kit',
#  ' First aid kit]',
#  ' Fischer Cooktop 2 bocas gas stove',
#  ' Fischer electric stove',
#  ' Fischer oven',
#  ' Fischer stainless steel gas stove',
#  ' Fischer stainless steel oven',
#  ' Fitness center',
#  ' Fog\\u00e3o 4 bocas Itatiaia com forno e acendimento manual gas stove',
#  ' Fog\\u00e3o 4 bocas Itatiaia com forno e acendimento manual oven',
#  ' Fog\\u00e3o Eletrolux de 4 bocas com forno stainless steel oven',
#  ' Fog\\u00e3o \\u00e0 g\\u00e1s de 4 bocas gas stove',
#  ' Fog\\u00e3o a gas de 4 bocas gas stove',
#  ' Fog\\u00e3o a gas gas stove',
#  ' Fog\\u00e3o com forno gas stove',
#  ' Fog\\u00e3o com forno oven',
#  ' Fog\\u00e3o de 2 bocas a g\\u00e1s. stove',
#  ' Fog\\u00e3o el\\u00e9trico de 2 bocas stove',
#  ' Fog\\u00e3o industrial 2 bocas - Metalnox gas stove',
#  ' Forninho Eletrico Pequeno para Esquentar P\\u00e3es etc oven',
#  ' Forninho Super Fryer da Oster stainless steel oven',
#  ' Forninho el\\u00e9trico e forno a lenha oven',
#  ' Forninho eletrico stainless steel oven',
#  ' Forno El\\u00e9trico Marca Layr Modelo Super Luxo com Grill  (220 Volts) oven',
#  ' Forno acoplado no fog\\u00e3o a g\\u00e1s. oven',
#  ' Forno do fog\\u00e3o Esmaltec oven',
#  ' Forno do fog\\u00e3o oven',
#  ' Forno do pr\\u00f3prio fog\\u00e3o oven',
#  ' Forno el\\u00e9trico de 40l oven',
#  ' Forno el\\u00e9trico pequeno na cozinha compartilhada.  oven',
#  ' Fr\\u00f3es free consul refrigerator',
#  ' Francis',
#  ' Francis body soap',
#  ' Frascos individuais de xampu com condicionador. shampoo',
#  ' Free carport on premises',
#  ' Free carport on premises \\u2013 1 space',
#  ' Free carport on premises \\u2013 2 spaces',
#  ' Free driveway parking on premises',
#  ' Free driveway parking on premises \\u2013 1 space',
#  ' Free driveway parking on premises \\u2013 2 spaces',
#  ' Free dryer',
#  ' Free dryer \\u2013 In building',
#  ' Free dryer \\u2013 In unit',
#  ' Free parking garage on premises',
#  ' Free parking garage on premises \\u2013 1 space',
#  ' Free parking garage on premises \\u2013 2 spaces',
#  ' Free parking garage on premises \\u2013 2 spaces]',
#  ' Free parking garage on premises \\u2013 3 spaces',
#  ' Free parking garage on premises \\u2013 600 spaces',
#  ' Free parking on premises',
#  ' Free parking on premises \\u2013 1 space',
#  ' Free parking on premises \\u2013 2 spaces',
#  ' Free parking on premises \\u2013 4 spaces',
#  ' Free parking on premises]',
#  ' Free residential garage on premises',
#  ' Free residential garage on premises \\u2013 1 space',
#  ' Free residential garage on premises \\u2013 10 spaces',
#  ' Free residential garage on premises \\u2013 2 spaces',
#  ' Free residential garage on premises \\u2013 3 spaces',
#  ' Free residential garage on premises \\u2013 4 spaces',
#  ' Free residential garage on premises \\u2013 6 spaces',
#  ' Free street parking',
#  ' Free street parking]',
#  ' Free washer',
#  ' Free washer \\u2013 In building',
#  ' Free washer \\u2013 In unit',
#  ' Free wifi',
#  ' Free wifi]',
#  ' Freezer',
#  ' Frigobar Consul refrigerator',
#  ' Frigobar Electrolux Azul refrigerator',
#  ' Frigobar dentro quarto refrigerator',
#  ' Full kitchen',
#  ' GE Frost Free refrigerator',
#  ' GE stainless steel electric stove',
#  ' GE stainless steel oven',
#  ' GRANADO body soap',
#  ' G\\u00e1s oven',
#  ' Game console',
#  ' Game console: Nintendo Wii',
#  ' Game console: PS3',
#  ' Game console: PS4',
#  ' Game console: PS4 and Xbox 360',
#  ' Game console: PS4 and Xbox One',
#  ' Game console: Xbox 360',
#  ' Garnier shampoo',
#  ' Gas stove',
#  ' Geladeira 2 portas frostfree refrigerator',
#  ' Geladeira Consul refrigerator',
#  ' Geladeira refrigerator',
#  ' Gen\\u00e9ria de Hotel body soap',
#  ' Gen\\u00e9rica de Hot\\u00e9is conditioner',
#  ' Gen\\u00e9rico de Hotel shampoo',
#  ' Geral electric stove',
#  ' Geral gas stove',
#  ' Gold conditioner',
#  ' Gold shampoo',
#  ' Granado',
#  ' Granado - linha Carioca body soap',
#  ' Granado - linha Carioca conditioner',
#  ' Granado - linha Carioca shampoo',
#  ' Granado body soap',
#  ' Granado conditioner',
#  ' Granado shampoo',
#  ' Granado. body soap',
#  ' Gym',
#  ' Gym in building',
#  ' Gym nearby',
#  ' Gym]',
#  ' HBO Max',
#  ' HDTV',
#  ' HDTV with Amazon Prime Video',
#  ' HDTV with Apple TV',
#  ' HDTV with Chromecast',
#  ' HDTV with HBO Max',
#  ' HDTV with Netflix',
#  ' HDTV with premium cable',
#  ' HDTV with standard cable',
#  ' HOME THEATER sound system with aux',
#  ' HOMETHEATER sound system with aux',
#  ' Hair dryer',
#  ' Hair dryer]',
#  ' Hangers',
#  ' Hangers]',
#  ' Harus body soap',
#  ' Harus conditioner',
#  ' Heated pool',
#  ' Heating',
#  ' High chair',
#  ' High chair]',
#  ' Host greets you',
#  ' Host greets you]',
#  ' Hot tub',
#  ' Hot tub]',
#  ' Hot water',
#  ' Hot water kettle',
#  ' Hot water]',
#  ' House bikes',
#  ' Housekeeping',
#  ' I-Home Bluetooth sound system',
#  ' INDUSTRIAL refrigerator',
#  ' INDUSTRIAL stainless steel gas stove',
#  ' Importado electric stove',
#  ' Indoor fireplace',
#  ' Indoor fireplace]',
#  ' Indu\\u00e7\\u00e3o da Eletrolux e um outro eletrico induction stove',
#  ' Induction stove',
#  ' Iron',
#  ' JBL  Bluetooth sound system',
#  ' JBL Bluetooth sound system',
#  ' JBL sound system with Bluetooth and aux',
#  ' JBL sound system with aux]',
#  ' Jbl Bluetooth sound system',
#  ' Johnson & Johnson body soap',
#  ' Johnson body soap',
#  " Johnson's",
#  ' Johnsons body soap',
#  ' Junto com o fog\\u00e3o - El\\u00e9trico e a g\\u00e1s stainless steel oven',
#  ' Kayak',
#  ' Kerafix Shampoo creme sem sal (Euroderm) shampoo',
#  ' Keurig coffee machine',
#  ' Keypad',
#  ' Kit de Higiene \\u00e9 fornecido body soap',
#  ' Kitchen',
#  ' Kitchen]',
#  " L'Occitane conditioner",
#  " L'Occitane shampoo",
#  ' LG Bluetooth sound system',
#  ' LG Side by Side refrigerator',
#  ' LG Soundbar Bluetooth sound system',
#  ' LG oven',
#  ' LG sound system with aux',
#  ' LOFRA stainless steel oven',
#  ' LUX ',
#  ' LUX E OUTROS body soap',
#  ' LUX body soap',
#  ' L\\u00b4Occitane En Provence Purifying Freshness shampoo',
#  ' L\\u00edquido   body soap',
#  ' L\\u00edquido  body soap',
#  ' L\\u00edquido body soap',
#  ' L\\u00edquido local body soap',
#  ' Lake access',
#  ' Lampada Speaker Bluetooth sound system',
#  ' Laundromat nearby',
#  ' Laundry services',
#  ' Lavanda body soap',
#  ' Le Cook electric stove',
#  ' Localizado no 3\\u00ba andar no ed\\u00edficio em frente com elevador. refrigerator',
#  ' Lock on bedroom door',
#  ' Lock on bedroom door]',
#  ' Lockbox',
#  ' Long term stays allowed',
#  ' Long term stays allowed]',
#  ' Luggage dropoff allowed',
#  ' Luggage dropoff allowed]',
#  ' Lux',
#  ' Lux (l\\u00edquido)  body soap',
#  ' Lux - Rexona body soap',
#  ' Lux Luxo',
#  ' Lux body soap',
#  ' Lux ou Nivea body soap',
#  ' Lux ou Palmolive body soap',
#  ' Lux ou similar body soap',
#  ' M\\u00e3os e banho body soap',
#  ' Micro System Philips 300w Rms sound system with aux',
#  ' Micro ondas oven',
#  ' Microwave',
#  ' Microwave]',
#  ' Midea refrigerator',
#  ' Mini fridge',
#  ' Mini fridge]',
#  ' Minibar',
#  ' Minist\\u00e9rio do Desenvolvimento Agr\\u00e1rio e SEBRAE.  body soap',
#  ' Minist\\u00e9rio do Desenvolvimento Agr\\u00e1rio e SEBRAE.  conditioner',
#  ' Minist\\u00e9rio do Desenvolvimento Agr\\u00e1rio e SEBRAE.  shampoo',
#  ' Moderno apartamento com WIFI conditioner',
#  ' Mosquito net',
#  ' NA body soap',
#  ' NA conditioner',
#  ' NAD sound system with aux',
#  ' NIVEA body soap',
#  ' N\\u00e3o \\u00e9 um fog\\u00e3o ',
#  ' N\\u00e3o \\u00e9 um fog\\u00e3o \\u00e9 um fogareiro el\\u00e9trico electric stove',
#  ' N\\u00e3o h\\u00e1 reposi\\u00e7\\u00e3o body soap',
#  ' N\\u00e3o h\\u00e1 reposi\\u00e7\\u00e3o conditioner',
#  ' N\\u00e3o h\\u00e1 reposi\\u00e7\\u00e3o shampoo',
#  ' N\\u00e3o sei. Tem shampoo e condicionador. conditioner',
#  ' N\\u00edvea  body soap',
#  ' N\\u00edvea body soap',
#  ' N\\u00edvea conditioner',
#  ' N\\u00edvea ou Granado body soap',
#  ' Na TV e YOUTUBE sound system',
#  ' Natura TodoDia body soap]',
#  ' Natura TodoDia conditioner',
#  ' Natura TodoDia shampoo',
#  ' Natura body soap',
#  ' Natura conditioner',
#  ' Natura shampoo',
#  ' Naturis body soap',
#  ' Naturis shampoo',
#  " Natury's Flores Estoril 10g Hipoalerg\\u00eanico. body soap",
#  " Natury's Sache 10ml 2x1 (shampoo e condicionador)  conditioner",
#  ' Nespresso machine',
#  ' Netflix',
#  ' Nivea  Dove body soap',
#  ' Nivea body soap',
#  ' Nivea em barra. body soap',
#  ' Nivea ou Dove body soap',
#  ' Nivea ou similar body soap',
#  ' No kit conditioner',
#  ' Normal gas stove',
#  ' Nrastemp stainless steel oven',
#  ' O forno est\\u00e1 com defeito. Mas os queimadores em bom estado gas stove',
#  ' O xampu j\\u00e1 \\u00e9 com condicionador. conditioner',
#  ' OX  conditioner',
#  ' OX shampoo',
#  ' Onsite bar',
#  ' Onsite bar \\u2014 Lobby Bar',
#  ' Onsite restaurant \\u2014 Fidalgo Restaurant',
#  ' Onsite restaurant \\u2014 Granada Restaurant',
#  ' Onsite restaurant \\u2014 Restaurante Cafe Le Soleil',
#  ' Oster stainless steel oven',
#  ' Outdoor dining area',
#  ' Outdoor dining area]',
#  ' Outdoor furniture',
#  ' Outdoor pool',
#  ' Outdoor pool]',
#  ' Outdoor shower',
#  ' Outlet covers',
#  ' Oven',
#  ' PALMOLIVE OU EQUIVALENTE  body soap',
#  ' PANASONIC refrigerator',
#  ' PHEBO body soap',
#  ' PHILIPS sound system with Bluetooth and aux',
#  ' Pack \\u2019n Playtravel crib',
#  ' Paid dryer \\u2013 In building',
#  ' Paid dryer \\u2013 In unit',
#  ' Paid parking garage off premises',
#  ' Paid parking garage on premises',
#  ' Paid parking garage on premises \\u2013 1 space',
#  ' Paid parking garage on premises \\u2013 100 spaces',
#  ' Paid parking garage on premises \\u2013 2 spaces',
#  ' Paid parking garage on premises \\u2013 3 spaces',
#  ' Paid parking lot off premises',
#  ' Paid parking lot on premises',
#  ' Paid parking lot on premises \\u2013 1 space',
#  ' Paid parking lot on premises \\u2013 10 spaces',
#  ' Paid parking lot on premises \\u2013 100 spaces',
#  ' Paid parking lot on premises \\u2013 30 spaces',
#  ' Paid parking off premises',
#  ' Paid parking on premises',
#  ' Paid street parking off premises',
#  ' Paid valet parking on premises',
#  ' Paid valet parking on premises \\u2013 1 space',
#  ' Paid valet parking on premises \\u2013 20 spaces',
#  ' Paid washer',
#  ' Paid washer \\u2013 In building',
#  ' Paid washer \\u2013 In building]',
#  ' Paid washer \\u2013 In unit',
#  ' Palmolive body soap',
#  ' Palmolive ou similar. body soap',
#  ' Panasonic refrigerator',
#  ' Pantene Provee conditioner]',
#  ' Pantene conditioner',
#  ' Pantene pro-v',
#  ' Pantene shampoo',
#  ' Panthene conditioner',
#  ' Patio or balcony',
#  ' Pequeno',
#  ' Pets allowed',
#  ' Phebo body soap',
#  ' Phebo liquido body soap',
#  ' Philco 46 l stainless steel oven',
#  ' Philco oven',
#  ' Philco stainless steel oven',
#  ' Philips',
#  ' Philips Bluetooth sound system',
#  ' Philips sound system with aux',
#  ' Philips sound system with aux]',
#  ' Phillips sound system with Bluetooth and aux',
#  ' Piano',
#  ' Ping pong table',
#  ' Pioneer sound system with aux',
#  ' Pocket wifi',
#  ' Pool',
#  ' Pool table',
#  ' Pool]',
#  ' Port\\u00e1til  electric stove',
#  ' Portable air conditioning',
#  ' Portable fans',
#  ' Portable heater',
#  ' Pour-over coffee',
#  ' Private entrance',
#  ' Private entrance]',
#  ' Private fenced garden or backyard',
#  ' Private garden or backyard',
#  ' Private gym',
#  ' Private gym in building',
#  ' Private gym nearby',
#  ' Private hot tub',
#  ' Private indoor heated pool',
#  ' Private indoor heated rooftop pool',
#  ' Private indoor heated saltwater pool',
#  ' Private indoor lap pool',
#  ' Private indoor pool',
#  ' Private indoor rooftop pool',
#  ' Private outdoor heated olympic-sized lap pool',
#  ' Private outdoor heated rooftop pool',
#  ' Private outdoor pool',
#  ' Private outdoor rooftop pool',
#  ' Private patio or balcony',
#  ' Private pool',
#  ' Private rooftop pool',
#  ' Private sauna',
#  ' Protect body soap',
#  ' Protex body soap',
#  ' Protex ou Phebo body soap',
#  ' Protex shampoo]',
#  ' Q3 Bluetooth sound system',
#  ' REFRIGERADOR GRANDE COM FREEZER SUPERIOR refrigerator',
#  ' Realgems - Capim Lim\\u00e3o body soap',
#  ' Receiver com caixas embutidas sound system with aux',
#  ' Record player',
#  ' Refrigerador Consul 300l FrostFree refrigerator]',
#  ' Refrigerador Frost Free Duplex Electrolux refrigerator',
#  ' Refrigerador pequeno',
#  ' Refrigerator',
#  ' Refrigerator]',
#  ' Rexona body soap',
#  ' Rice maker',
#  ' Rio Spot Homes conditioner',
#  ' Roku',
#  ' Rooftop pool \\u2014 outdoor',
#  ' Rooftop pool with poolside bar \\u2014 outdoor',
#  ' Room service',
#  ' Room-darkening shades',
#  ' Room-darkening shades]',
#  ' SABONETE L\\u00cdQUIDO NOS BANHEIROS body soap',
#  ' SONY sound system with Bluetooth and aux',
#  ' Sabonete body soap',
#  ' Sabonete de Erva Doce',
#  ' Sabonete em barra para banho body soap',
#  ' Sabonete l\\u00edquido  body soap',
#  ' Sabonete l\\u00edquido (variado) body soap',
#  ' Sabonete l\\u00edquido generico body soap',
#  ' Sabonete l\\u00edquido na pia do banheiro sabonete descart\\u00e1vel body soap',
#  ' Sabonete l\\u00edquido sempre dispon\\u00edvel. body soap',
#  ' Safe',
#  ' Safe]',
#  ' Samsung Side by Side refrigerator',
#  ' Samsung refrigerator',
#  ' Samsung sound system with aux',
#  ' Sauna',
#  ' Security cameras on property',
#  ' Security cameras on property]',
#  ' Seda conditioner',
#  ' Seda shampoo',
#  ' Self check-in',
#  ' Self check-in]',
#  ' Self-parking \\u2014 R$25day',
#  ' Self-parking \\u2014 R$35day',
#  ' Self-parking \\u2014 R$40stay',
#  ' Self-parking \\u2014 R$50stay',
#  ' Sem marca body soap',
#  ' Shampoo',
#  ' Shampoo e Condicionador 2x1 Realgems - Capim Lim\\u00e3o conditioner',
#  ' Shampoo e Condicionador 2x1 Realgems - Capim Lim\\u00e3o shampoo',
#  ' Shared fenced garden or backyard',
#  ' Shared garden or backyard',
#  ' Shared gym',
#  ' Shared gym in building',
#  ' Shared gym nearby',
#  ' Shared heated pool',
#  ' Shared hot tub',
#  ' Shared indoor heated pool',
#  ' Shared indoor lap pool',
#  ' Shared indoor pool',
#  ' Shared indoor rooftop pool',
#  ' Shared lap pool',
#  ' Shared outdoor heated infinity lap pool',
#  ' Shared outdoor heated lap pool',
#  ' Shared outdoor heated pool',
#  ' Shared outdoor infinity pool',
#  ' Shared outdoor lap pool',
#  ' Shared outdoor olympic-sized rooftop lap pool',
#  ' Shared outdoor pool',
#  ' Shared outdoor rooftop pool',
#  ' Shared patio or balcony',
#  ' Shared pool',
#  ' Shared rooftop pool',
#  ' Shared sauna',
#  ' Shower gel',
#  ' Single level home',
#  ' Single level home]',
#  ' Ski-inSki-out',
#  ' Ski-inSki-out]',
#  ' Smart lock',
#  ' Smoke alarm',
#  ' Smoke alarm]',
#  ' Smoking allowed',
#  ' Soap body soap',
#  ' Sony sound system',
#  ' Sony sound system with Bluetooth and aux',
#  ' Sony sound system with aux]',
#  ' Sound system',
#  ' Sound system with Bluetooth and aux',
#  ' Sound system with aux',
#  ' Springer  conditioner',
#  ' Stainless steel electric stove',
#  ' Stainless steel gas stove',
#  ' Stainless steel induction stove',
#  ' Stainless steel oven',
#  ' Stainless steel stove',
#  ' Stove',
#  ' Stove]',
#  ' Suggar cooktop 2 bocas gas stove',
#  ' Suitable for events',
#  ' TRAMONTINA stainless steel gas stove',
#  ' TV',
#  ' TV with Amazon Prime Video',
#  ' TV with Apple TV',
#  ' TV with Chromecast',
#  ' TV with Netflix',
#  ' TV with premium cable',
#  ' TV with standard cable',
#  ' TV with standard cable]',
#  ' TV]',
#  ' Table corner guards',
#  ' Tipo amenities hotel body soap',
#  ' Tipo amenities hotel shampoo',
#  ' Tipo hotel body soap',
#  ' Toaster',
#  ' Toaster]',
#  ' Todos os Banheiros contam com Shampoo e Condicionador conditioner',
#  ' Toiletries',
#  ' Toiletries]',
#  ' Tramontina gas stove',
#  ' Tramontina stainless steel electric stove',
#  ' Tramontina stainless steel induction stove',
#  ' Trash compactor',
#  ' Tresem\\u00e9GranadoSeda conditioner',
#  ' Tresem\\u00e9GranadoSeda shampoo',
#  ' Tresemm\\u00e9 conditioner',
#  ' Tresemm\\u00e9 shampoo',
#  ' UBL Bluetooth sound system',
#  ' Ubon body soap',
#  ' Utilizados n\\u00f3s hot\\u00e9is body soap',
#  ' VENAX gas stove',
#  ' Valet parking \\u2014 R$25day',
#  ' Variada body soap',
#  ' Venax com forno stainless steel gas stove',
#  ' Venax oven',
#  ' Venax stainless steel oven',
#  ' Venix  retr\\u00f4 2 bocas chamas altas com forninho gas stove',
#  ' Verveine Gel Douche Shower Gel L\\u00b4Occitane body soap',
#  ' Vicini alum\\u00ednio 2 bocas electric stove',
#  ' Vide foto gas stove',
#  ' Vide foto refrigerator',
#  ' Viking gas stove',
#  ' Walita oven',
#  ' Washer',
#  ' Washer \\u2013\\u00a0In building',
#  ' Washer \\u2013\\u00a0In unit',
#  ' Waterfront',
#  ' Whirlpool USA refrigerator',
#  ' Wifi',
#  ' Wifi \\u2013 1 Mbps',
#  ' Wifi \\u2013 10 Mbps',
#  ' Wifi \\u2013 100 Mbps',
#  ' Wifi \\u2013 12 Mbps',
#  ' Wifi \\u2013 120 Mbps',
#  ' Wifi \\u2013 125 Mbps',
#  ' Wifi \\u2013 140 Mbps',
#  ' Wifi \\u2013 15 Mbps',
#  ' Wifi \\u2013 150 Mbps',
#  ' Wifi \\u2013 2 Mbps',
#  ' Wifi \\u2013 20 Mbps',
#  ' Wifi \\u2013 200 Mbps',
#  ' Wifi \\u2013 220 Mbps',
#  ' Wifi \\u2013 235 Mbps',
#  ' Wifi \\u2013 240 Mbps',
#  ' Wifi \\u2013 25 Mbps',
#  ' Wifi \\u2013 250 Mbps',
#  ' Wifi \\u2013 30 Mbps',
#  ' Wifi \\u2013 300 Mbps',
#  ' Wifi \\u2013 30000 Mbps',
#  ' Wifi \\u2013 35 Mbps',
#  ' Wifi \\u2013 39 Mbps',
#  ' Wifi \\u2013 40 Mbps',
#  ' Wifi \\u2013 400 Mbps',
#  ' Wifi \\u2013 5 Mbps',
#  ' Wifi \\u2013 50 Mbps',
#  ' Wifi \\u2013 500 Mbps',
#  ' Wifi \\u2013 60 Mbps',
#  ' Wifi \\u2013 600 Mbps',
#  ...]

# %% [markdown]
# # Question 3: Estimate price of a new offer

# %%
# Creating a new df with just the information that will be used in our model:
df_model = df[[
       'neighbourhood_cleansed', 'latitude', 
       'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
       'bedrooms', 'beds', 'price']]

# Verify the types of this subset in order to put the data into a trainable format.
df_model.dtypes
# Out:
# neighbourhood_cleansed     object
# latitude                  float64
# longitude                 float64
# property_type              object
# room_type                  object
# accommodates                int64
# bathrooms                 float64
# bedrooms                  float64
# beds                      float64
# price                      object
# dtype: object

# %%
# Verify which data has Nan Values and how much of it are Nan
df_model.isnull().sum() / df_model.shape[0]
# Out:
# neighbourhood_cleansed    0.0
# latitude                  0.0
# longitude                 0.0
# property_type             0.0
# room_type                 0.0
# accommodates              0.0
# bathrooms                 1.0
# bedrooms                  0.0
# beds                      0.0
# price                     0.0
# dtype: float64

# %%
#As the bathrooms column is always null, I chose to remove it.
df_model.drop(['bathrooms'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# As 1 bedroom and 1 bed should be the minimum for representing a room in Airbnb, I chose to replace nan by 1:
df_model['bedrooms'].fillna(1, inplace=True)
df_model['beds'].fillna(1, inplace=True)
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:6383: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
# Convert categorical data into factors using the factorize
df_model['neighbourhood_cleansed'] = df_model['neighbourhood_cleansed'].factorize()[0]
df_model['property_type'] = df_model['property_type'].factorize()[0]
df_model['room_type'] = df_model['room_type'].factorize()[0]
# Out:
# /var/folders/pt/zrk7x6q129l0kc42bc7l9fhw0000gn/T/ipykernel_619/2620458399.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['neighbourhood_cleansed'] = df_model['neighbourhood_cleansed'].factorize()[0]
# /var/folders/pt/zrk7x6q129l0kc42bc7l9fhw0000gn/T/ipykernel_619/2620458399.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['property_type'] = df_model['property_type'].factorize()[0]
# /var/folders/pt/zrk7x6q129l0kc42bc7l9fhw0000gn/T/ipykernel_619/2620458399.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['room_type'] = df_model['room_type'].factorize()[0]

# %%
#Convert price to float
df_model['price'] = df_model['price'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# /var/folders/pt/zrk7x6q129l0kc42bc7l9fhw0000gn/T/ipykernel_619/2266791237.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['price'] = df_model['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# As there is no free rooms, I opted to remove the rooms with 0 on price:
df_model = df_model[df_model.price != 0]

# %%
# Verify values and ranges
df_model.describe()
# Out:
#        neighbourhood_cleansed      latitude     longitude  property_type  \
# count            23628.000000  23628.000000  23628.000000   23628.000000
# mean                12.289572    -22.966150    -43.249287       4.046724
# std                 20.896943      0.035113      0.097134       8.676214
# min                  0.000000    -23.072620    -43.720990       0.000000
# 25%                  0.000000    -22.984680    -43.306940       1.000000
# 50%                  4.000000    -22.972000    -43.196370       1.000000
# 75%                 13.000000    -22.951970    -43.186300       3.000000
# max                152.000000    -22.749690    -43.104400      86.000000
#
#           room_type  accommodates      bedrooms          beds          price
# count  23628.000000  23628.000000  23628.000000  23628.000000   23628.000000
# mean       0.302776      4.140681      1.662900      2.543465     751.551888
# std        0.526519      2.493216      1.061291      2.283689    5478.003352
# min        0.000000      1.000000      1.000000      0.000000      33.000000
# 25%        0.000000      2.000000      1.000000      1.000000     150.000000
# 50%        0.000000      4.000000      1.000000      2.000000     256.000000
# 75%        1.000000      5.000000      2.000000      3.000000     511.000000
# max        3.000000     16.000000     30.000000     91.000000  586229.000000

# %%
df_model.columns
# Out:
# Index(['neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bedrooms', 'beds', 'price'],
#       dtype='object')

# %% [markdown]
# ## Starting the creation of the model and training of it

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

X = df_model[['neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
              'room_type', 'accommodates', 'bedrooms', 'beds']]
y = df_model[['price']]

#Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .20, random_state=14) 

lm_model = LinearRegression(normalize=True) # Instantiate
lm_model.fit(X_train, y_train) #Fit

#Predict and score the model
y_test_preds = lm_model.predict(X_test)

mean_error = mean_absolute_error(y_test, y_test_preds)
mean_error
# Out:
# 666.9192270895346
